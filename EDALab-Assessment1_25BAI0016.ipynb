# %%
import pandas as pd
import numpy as n
from google.colab import drive
drive.mount('/content/drive')
df = pd.read_csv('/content/drive/MyDrive/chess_games.csv')
# Out:
# Mounted at /content/drive

# %%
print("Showing First 5 Lines of Data:")
print(df.head(5))

print("\nDescriptive statistics")
print(df.describe())

resp = df[df['opening_response'].notna()]
print(resp)
# Out:
# Showing First 5 Lines of Data:
#    game_id  rated  turns victory_status winner time_increment       white_id  \
# 0        1  False     13    Out of Time  White           15+2       bourgris
# 1        2   True     16         Resign  Black           5+10           a-00
# 2        3   True     61           Mate  White           5+10         ischia
# 3        4   True     61           Mate  White           20+0  daniamurashov
# 4        5   True     95           Mate  White           30+3      nik221107
#
#    white_rating      black_id  black_rating  \
# 0          1500          a-00          1191
# 1          1322     skinnerua          1261
# 2          1496          a-00          1500
# 3          1439  adivanov2009          1454
# 4          1523  adivanov2009          1469
#
#                                                moves opening_code  \
# 0  d4 d5 c4 c6 cxd5 e6 dxe6 fxe6 Nf3 Bb4+ Nc3 Ba5...          D10
# 1  d4 Nc6 e4 e5 f4 f6 dxe5 fxe5 fxe5 Nxe5 Qd4 Nc6...          B00
# ...

# %%
print("Declined Games:\n")
declined_games = df[df['opening_fullname'].str.contains('Declined', na=False)]
display(declined_games.head())
print(f"Total Declined Games: {len(declined_games)}")

print("\nLesser Used Gambits (Top 10 least frequent gambits with at least 2 occurrences):\n")
gambit_openings = df[df['opening_fullname'].str.contains('Gambit', na=False)]['opening_fullname'].value_counts()
lesser_gambits = gambit_openings[gambit_openings > 1].tail(10)
print(f"Number of unique gambits: {gambit_openings.shape[0]}")
print(lesser_gambits)

print("\nExtremely High Rated Games (both players rating over 2200):\n")
high_rated_games = df[(df['white_rating'] > 2200) & (df['black_rating'] > 2200)]
display(high_rated_games.head())
print(f"Total High Rated Games: {len(high_rated_games)}")

print("\nNon-Null Counts for all columns:\n")
print(df.count())

print("\nResigned Games:\n")
resigned_games = df[df['victory_status'] == 'Resign']
display(resigned_games.head())
print(f"Total Resigned Games: {len(resigned_games)}")
# Out:
# Declined Games:
#      game_id  rated  turns victory_status winner time_increment     white_id  \
# 107      108   True     91         Resign  White           10+0    totoymate
# 110      111   True     18         Resign  Black           10+0      avelez8
# 113      114   True    111           Mate  White           15+0    hafedfree
# 149      150   True     18         Resign  Black           25+0       sassou
# 207      208  False    118         Resign  Black            7+2  blassterkal
#
#      white_rating       black_id  black_rating  \
# 107          1721        avelez8          1750
# 110          1749  yolandoparada          1631
# 113          1729           cdvh          1795
# 149          1228       martin74          1626
# 207          1431        taranga          1289
#
#                                                  moves opening_code  \
# 107  d4 d5 c4 e6 Nf3 Nf6 Bg5 Be7 e3 c6 Bd3 dxc4 Bxc...          D30
# ...

# %%
print("### Dataset Overview\n")
print("This section provides a general overview of the chess games dataset, including column information, data types, and basic descriptive statistics.")

print("\nDataFrame Information (df.info()):\n")
df.info()

print("\n\nDataFrame Descriptive Statistics (df.describe()):\n")
display(df.describe(include='all'))
# Out:
# ### Dataset Overview
#
# This section provides a general overview of the chess games dataset, including column information, data types, and basic descriptive statistics.
#
# DataFrame Information (df.info()):
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20058 entries, 0 to 20057
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   game_id            20058 non-null  int64
#  1   rated              20058 non-null  bool
#  2   turns              20058 non-null  int64
#  3   victory_status     20058 non-null  object
#  4   winner             20058 non-null  object
#  5   time_increment     20058 non-null  object
#  6   white_id           20058 non-null  object
#  7   white_rating       20058 non-null  int64
#  8   black_id           20058 non-null  object
#  9   black_rating       20058 non-null  int64
#  10  moves              20058 non-null  object
# ...
